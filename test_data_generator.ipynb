# %%
import boto3
import json
import psycopg2
import base64
from faker import Faker
import uuid
from datetime import datetime, timedelta
import random
import csv
import io

# %% [markdown]
# ## Set Parameters

# %%
env='dev'
region_name = 'us-east-1'
account_id=183286346090
secret_name = f'ticketing-postgres-credentials-{env}'
bucket_name = f'ticketing-data-{account_id}-{env}'

# %% [markdown]
# ## Get Postgres DB secret

# %%
def get_secret(secret_name):
    """Retrieves the secret from Secrets Manager."""
    
    session = boto3.session.Session()
    client = session.client(
        service_name='secretsmanager',
        region_name=region_name
    )

    try:
        get_secret_value_response = client.get_secret_value(
            SecretId=secret_name
        )
    except Exception as e:
        if e.response['Error']['Code'] == 'DecryptionFailureException':
            # The secret can't be decrypted using the provided KMS key.
            raise e
        elif e.response['Error']['Code'] == 'InternalServiceErrorException':
            # An error occurred inside Secrets Manager.
            raise e
        elif e.response['Error']['Code'] == 'InvalidParameterException':
            # You provided an invalid value for a parameter.
            raise e
        elif e.response['Error']['Code'] == 'InvalidRequestException':
            # You provided a bad request.
            raise e
        elif e.response['Error']['Code'] == 'ResourceNotFoundException':
            # The requested secret was not found.
            raise e
    else:
        # Decrypted secrets are available directly.
        if 'SecretString' in get_secret_value_response:
            secret = get_secret_value_response['SecretString']
            return json.loads(secret)  # Return secret as a dictionary
        else:
            decoded_binary_secret = base64.b64decode(get_secret_value_response['SecretBinary'])
            return decoded_binary_secret

# %%
try:
    secret = get_secret(secret_name)
    db_host = secret["host"]
    db_name = secret["dbname"]
    db_user = secret["username"]
    db_password = secret["password"]    

except Exception as e:
    print(f"Error retrieving secret or connecting to database: {e}")

# %% [markdown]
# ## Create Tables

# %%
def create_tables(conn):
    """Creates the tables in the PostgreSQL database."""

    cursor = conn.cursor()

    tables = {
        "venues": """
            CREATE TABLE venues (
                venue_id UUID PRIMARY KEY DEFAULT gen_random_uuid(),
                venue_name VARCHAR(255) NOT NULL,
                location VARCHAR(255)
            )
        """,
        "organizers": """
            CREATE TABLE organizers (
                organizer_id UUID PRIMARY KEY DEFAULT gen_random_uuid(),
                organizer_name VARCHAR(255) NOT NULL
            )
        """,
        "resellers": """
            CREATE TABLE resellers (
                reseller_id UUID PRIMARY KEY DEFAULT gen_random_uuid(),
                reseller_name VARCHAR(255) NOT NULL,
                location VARCHAR(255)
            )
        """,
        "customers": """
            CREATE TABLE customers (
                customer_id UUID PRIMARY KEY DEFAULT gen_random_uuid(),
                customer_name VARCHAR(255) NOT NULL
            )
        """,
        "sales_channels": """
            CREATE TABLE sales_channels (
                sales_channel_id UUID PRIMARY KEY DEFAULT gen_random_uuid(),
                channel_name VARCHAR(255) NOT NULL
            )
        """,
        "events": """
            CREATE TABLE events (
                event_id UUID PRIMARY KEY DEFAULT gen_random_uuid(),
                event_name VARCHAR(255) NOT NULL,
                event_type VARCHAR(100) NOT NULL,  -- Category of event (e.g., Concert, Sports, Theater)
                venue_id UUID REFERENCES venues(venue_id) NOT NULL
            )
        """,
        "sales": """
            CREATE TABLE sales (
                sale_id UUID PRIMARY KEY DEFAULT gen_random_uuid(),
                event_id UUID REFERENCES events(event_id) NOT NULL, -- Added event_id reference
                venue_id UUID REFERENCES venues(venue_id) NOT NULL,
                organizer_id UUID REFERENCES organizers(organizer_id) NOT NULL,
                reseller_id UUID REFERENCES resellers(reseller_id),
                customer_id UUID REFERENCES customers(customer_id) NOT NULL,
                sales_channel_id UUID REFERENCES sales_channels(sales_channel_id) NOT NULL,
                ticket_quantity INT NOT NULL,
                total_amount DECIMAL(10, 2) NOT NULL,
                sale_date TIMESTAMP NOT NULL
            )
        """,
        "partnerships": """
            CREATE TABLE partnerships (
                partnership_id UUID PRIMARY KEY DEFAULT gen_random_uuid(),
                organizer_id UUID REFERENCES organizers(organizer_id) NOT NULL,
                reseller_id UUID REFERENCES resellers(reseller_id) NOT NULL,
                commission_rate DECIMAL(5, 2) NOT NULL,
                start_date DATE,
                end_date DATE
            )
        """
    }

    for table_name, create_statement in tables.items():
        try:
            cursor.execute(create_statement)
            conn.commit()
            print(f"Table '{table_name}' created successfully.")
        except psycopg2.errors.DuplicateTable:
            print(f"Table '{table_name}' already exists.")
            conn.rollback()  # Rollback transaction in case of error
        except Exception as e:
            print(f"Error creating table '{table_name}': {e}")
            conn.rollback()

    cursor.close()

# %%
try:
    # Use the retrieved credentials to connect to PostgreSQL
    conn = psycopg2.connect(host=db_host, database=db_name, user=db_user, password=db_password)
    create_tables(conn)
except Exception as e:
    print(f"Error connecting to database: {e}")
finally:
    if conn:
        conn.close()

# %% [markdown]
# ## Populate test database with fake data

# %%
import uuid
from faker import Faker
from datetime import datetime, timedelta
from psycopg2.extras import register_uuid

# Register the UUID extension
register_uuid()

fake = Faker()

# Define a list of possible event types
EVENT_TYPES = ["Concert", "Sports", "Theater", "Conference", "Festival", "Exhibition"]

def populate_tables(conn, num_venues, num_organizers, num_resellers, num_customers, num_partnerships, num_events, num_sales):
    """Populates tables with fake data."""
    cursor = conn.cursor()

    try:
        # Venues
        venues = []
        for _ in range(num_venues):
            venue_id = uuid.uuid4()
            cursor.execute("INSERT INTO venues (venue_id, venue_name, location) VALUES (%s, %s, %s)", 
                           (venue_id, fake.company(), fake.city()))
            venues.append(venue_id)

        # Organizers
        organizers = []
        for _ in range(num_organizers):
            organizer_id = uuid.uuid4()
            cursor.execute("INSERT INTO organizers (organizer_id, organizer_name) VALUES (%s, %s)", 
                           (organizer_id, fake.company()))
            organizers.append(organizer_id)

        # Resellers
        resellers = []
        for _ in range(num_resellers):
            reseller_id = uuid.uuid4()
            cursor.execute("INSERT INTO resellers (reseller_id, reseller_name, location) VALUES (%s, %s, %s)", 
                           (reseller_id, fake.company(), fake.city()))
            resellers.append(reseller_id)

        # Customers
        customers = []
        for _ in range(num_customers):
            customer_id = uuid.uuid4()
            cursor.execute("INSERT INTO customers (customer_id, customer_name) VALUES (%s, %s)", 
                           (customer_id, fake.name()))
            customers.append(customer_id)

        # Partnerships
        for _ in range(num_partnerships):
            partnership_id = uuid.uuid4()
            partnership_start_date = fake.date_between(start_date=datetime(2017, 1, 1), end_date=datetime(2018, 12, 31))
            cursor.execute(
                "INSERT INTO partnerships (partnership_id, organizer_id, reseller_id, commission_rate, start_date, end_date) VALUES (%s, %s, %s, %s, %s, %s)",
                (partnership_id, 
                 fake.random_element(organizers), 
                 fake.random_element(resellers), 
                 fake.pydecimal(2, 2, positive=True), 
                 partnership_start_date, 
                 partnership_start_date + timedelta(days=+random.randint(720, 1080)))
            )

        # Sales Channels (fixed values)
        sales_channels = []
        for channel_name in ["on-the-site", "web", "mobile app"]:
            sales_channel_id = uuid.uuid4()
            cursor.execute("INSERT INTO sales_channels (sales_channel_id, channel_name) VALUES (%s, %s)", 
                           (sales_channel_id, channel_name))
            sales_channels.append(sales_channel_id)

        # Events
        events = []
        for _ in range(num_events):
            event_id = uuid.uuid4()
            venue_id = fake.random_element(venues)  # Ensure event is linked to a valid venue
            event_type = fake.random_element(EVENT_TYPES)
            event_name = fake.catch_phrase()
            cursor.execute("INSERT INTO events (event_id, event_name, event_type, venue_id) VALUES (%s, %s, %s, %s)", 
                           (event_id, event_name, event_type, venue_id))
            events.append((event_id, venue_id, event_name))  # Store event with its venue for reference

        # Sales
        for _ in range(num_sales):
            sale_id = uuid.uuid4()
            
            # Choose a random event and ensure the venue is consistent
            event_id, venue_id, event_name = fake.random_element(events)
            
            cursor.execute(
                "INSERT INTO sales (sale_id, event_id, venue_id, organizer_id, reseller_id, customer_id, sales_channel_id, ticket_quantity, total_amount, sale_date) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)",
                (
                    sale_id,
                    event_id,  # Reference the correct event
                    venue_id,  # Ensure the venue matches the event
                    fake.random_element(organizers),
                    fake.random_element(resellers) if _ % 3 != 0 else None,
                    fake.random_element(customers),
                    fake.random_element(sales_channels),
                    fake.random_int(min=1, max=10),
                    fake.pydecimal(5, 2, positive=True),
                    fake.date_time_between(start_date=datetime(2019, 1, 1), end_date=datetime(2022, 12, 31))
                )
            )

        conn.commit()
        print("Tables populated successfully.")
        return resellers, events

    except Exception as e:
        conn.rollback()
        print(f"Error populating tables: {e}")

    cursor.close()
    return None

# %%
conn = psycopg2.connect(host=db_host, database=db_name, user=db_user, password=db_password)    

# Populate tables with fake data
num_venues = 10
num_events = 5
num_organizers = 5
num_resellers = 3
num_customers = 500
num_partnerships = 5
num_sales = 5000

resellers, events = populate_tables(conn, num_venues, num_organizers, num_resellers, num_customers, num_partnerships, num_events, num_sales)

conn.close()
# Out:
# Tables populated successfully.

# %% [markdown]
# ## Populate CSV

# %%
import io
import csv
import random
import boto3
import uuid
from datetime import datetime, timedelta
from faker import Faker

fake = Faker()

def populate_csv_to_s3(bucket_name, resellers, events, num_files):
    """Populates a CSV file with fake ticketing data, including event_id, and uploads it to S3."""

    sales_channels = ["office", "web", "mobile app"]
    office_locations = ["New York", "London", "Tokyo", "Sydney", "San Francisco"]

    transaction_id_counter = 1  # Initialize a global transaction ID counter    

    try:
        for file_num in range(num_files):                
            # Generate a random date for each file
            start_date = datetime(2019, 1, 1)
            end_date = datetime(2020, 12, 31)
            time_between_dates = end_date - start_date
            days_between_dates = time_between_dates.days
            random_number_of_days = random.randrange(days_between_dates)
            random_date = start_date + timedelta(days=random_number_of_days)
            date_str = random_date.strftime("%m%d%Y")

            # Create filename for each file
            filename = f"DailySales_{date_str}_{random.choice(resellers)}.csv"

            # Generate a random number of rows for each file
            num_rows = random.randint(10, 300)

            # Create CSV data in memory using StringIO
            csv_data = io.StringIO()  
            fieldnames = [
                "Transaction ID", "Event Name", "Number of Purchased Tickets", "Total Amount",
                "Sales Channel", "Customer First Name", "Customer Last Name", "Office Location", "Created Date"
            ]
            writer = csv.DictWriter(csv_data, fieldnames=fieldnames)
            writer.writeheader()

            for _ in range(num_rows):
                transaction_id = transaction_id_counter
                transaction_id_counter += 1                
                event_name = random.choice(events)[2]                
                num_tickets = random.randint(1, 5)
                total_amount = round(random.uniform(20, 200), 2)
                sales_channel = random.choice(sales_channels)
                first_name = fake.first_name()
                last_name = fake.last_name()
                office_location = random.choice(office_locations) if sales_channel == "office" else ""
                created_date = random_date.strftime("%Y-%m-%d")

                writer.writerow({
                    "Transaction ID": transaction_id,
                    "Event Name": event_name,
                    "Number of Purchased Tickets": num_tickets,
                    "Total Amount": total_amount,
                    "Sales Channel": sales_channel,
                    "Customer First Name": first_name,
                    "Customer Last Name": last_name,
                    "Office Location": office_location,
                    "Created Date": created_date
                })

            # Upload to S3
            s3 = boto3.client('s3')
            csv_string = csv_data.getvalue()  
            s3.put_object(Bucket=bucket_name, Key="sales/"+filename, Body=csv_string.encode('utf-8'))

            print(f"Successfully uploaded {filename} to S3 bucket {bucket_name}")

    except Exception as e:
        print(f"Error: {e}")

num_files = 1000
populate_csv_to_s3(bucket_name, resellers, events, num_files)
# Out:
# Successfully uploaded DailySales_04242019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09052019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01202019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12302020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03202020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12212019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02202019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_05062020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03032019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04272019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02092019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02032019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01282020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03282020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03092019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04232019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01192019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_05212020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07142019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12042020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09282019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09282020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_06172019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07102020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09202020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03112020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10252019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01022019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11212020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02232020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02242019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11232019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09282020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07142020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07172019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07042019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08232020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04062020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_06152020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12082019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03272020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12202019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02282019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11062019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_05082019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01312020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07222019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_06112020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01242019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04022019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07192019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12202019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01052020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_06102019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03032020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09142019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01192020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01252019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12192019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08062020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10062020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04232020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01292019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09232019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04242020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04192020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01202020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11042020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_05072019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10162020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12162019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01102019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09252019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_06222019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07222020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10222020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01062020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04192020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09052020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12142020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03312020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_05082020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02272019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_06082020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08262020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07012020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12202020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07212020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10312020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10082020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07042020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12272019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02242020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_05082019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12082020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08162020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_05192019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12142019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11232019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08222020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01262019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08182020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11112020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11302020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_05202020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11162020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_06162019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_05122020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03272020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12052020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09022019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07172019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02022020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10042020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04232020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_06232020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10162019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10302020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08152019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08232020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11132019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08262020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09052019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08172019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_06272019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_06172019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01192020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12242019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02192020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09222020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08072020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01162019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02242019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08182019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03142019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12242020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_05182020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08082020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_06292019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09162020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10292019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_06242020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07142020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03212019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08212019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11122020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11042020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_06172019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11272019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_06042019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03192019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01282019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10262020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07052019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08072020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03102020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12232019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08122019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08202020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07212020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03142019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04072019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09192020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01182020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03132020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11162020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12192019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07082019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04122019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11142020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04292020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10142019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12272020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12142020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02042019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08022019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08172019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01152020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_05192020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07022020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03022019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12242019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_06212019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01042020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12242019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09042019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01102019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04022020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03262020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08122019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02272020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_05042020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03072019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07292019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08232019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11052020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_06032019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04182019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03162020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08282020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_06202019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08202019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03282019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02112019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04132020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02072020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03142020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11122019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01272019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01062020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10222020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07292020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04162020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10012020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09122019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03282019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12082019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10022019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09212020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08242020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01192020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09152019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_05122020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02172020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_06192020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09302020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08142020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08032019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_06102020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_06082019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09222020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11142019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09192019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_06092019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12172020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04012019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07292019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04092019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_05222019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01222019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04142020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_06232019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_06012020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03152019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10262019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03212020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11172019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12152019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12032020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10122020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02242019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01012020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03152020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02162020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_06012019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03302020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12102020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07262019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03062019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04042019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11182020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12032019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07292020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08222019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04272020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10222019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07312019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03292019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01212019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09062020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12122019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02252019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09122019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03082020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_05092019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04172019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_06102020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11232019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08042020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01282020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08182019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08042019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08172020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01202019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11112019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03152020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01222019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_06072019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07172020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11222020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11112019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10222019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01222019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04102019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11112019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09062019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10042019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10072019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04232019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08222019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12052019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02122020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10112019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11122020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_06232020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12192019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09222019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03262019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03262019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03292020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07022020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10072019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08092019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_06042020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09142019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_05132020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_05262020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10182020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12152020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_05172020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10062020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_05272019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01162020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12162019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04152020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01222019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12272020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_06112020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01082019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03302020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09242020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07262019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10282020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01082019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12302020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_05182020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02172020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04172019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10242020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02122020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01102019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03132020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_06082019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_06032020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11272020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09122019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03142020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_06252020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02032019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02172019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02252019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10142020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01182020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04102020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10262019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09192019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11242020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02252020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09262020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09102020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09272019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03222020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04112020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10212020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04052020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_06192019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07262020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03132020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01122020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07222019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07012019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12092020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01252019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01012020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08012019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# ...
# Successfully uploaded DailySales_11112020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03162020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07012020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01282020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02112019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_05232020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02092019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11112019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11232020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08282020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03202019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_05272020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04072020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09172019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10112020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11112019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02012020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07212019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12022019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_05022020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01052020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04012020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07172020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12012020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11082019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_05222019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02122020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02122019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04222019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04272020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02182019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11032020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_06032019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08072020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03242019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_05052019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08132019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12112020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08162019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04042019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01022019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02232019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12242019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03072019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11212020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12182019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04272019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04042020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07162020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12022020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01072019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07152019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10292020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08302020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_06112019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11092020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09212019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01062020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11242020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01312019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09212019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08162020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08192020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09032019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11302019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_05072020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07152019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10252019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01122019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11042019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_05022020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12112020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10032019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07022019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10182019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10242020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10062019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12282019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11032019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12062020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02042020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04072020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10122019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03272019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09102019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02262020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07292020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02142020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01272019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03262019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02172019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_05242019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_05222020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12262020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_07162020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03152019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_01202020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12262019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10052020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03222019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02192019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09192020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_05072019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03222020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_05022020_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09132019_76ef3a86-1d6b-48c1-bd5d-e62febbdc5f6.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11092020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_05222020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02062019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12202020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_10162020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_09112020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_05302020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08262020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_06062019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11052019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_03132020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_05052020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_02262019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_11162019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12202020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_08202020_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_05232019_4650b924-f628-4c30-b969-ab1a5108de00.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_12202020_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
# Successfully uploaded DailySales_04102019_4969f644-6082-4385-b2f3-1a87c54fb4ea.csv to S3 bucket ticketing-data-183286346090-dev
